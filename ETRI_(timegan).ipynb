# %% [markdown]
# <a href="https://colab.research.google.com/github/jihyeon602/ETRI_lifelog_dataset/blob/main/ETRI_(timegan).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 기본 경로지정, parquet 파일 확인

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ============================ 경로 설정 ============================ #
CONFIG = {
    "data_root": "/content/drive/MyDrive/Sleep/ch2025_data_items",  # ch2025_data_items 폴더
    "train_label_path": "/content/drive/MyDrive/Sleep/ch2025_metrics_train.csv",  # train 파일
    "submission_sample_path": "/content/drive/MyDrive/Sleep/ch2025_submission_sample.csv",  # 제출 파일
    "submission_save_path": "/content/drive/MyDrive/Sleep/submission_file/submission13_timegan.csv",  # 제출파일 저장경로
}
# =================================================================== #

# %%
# 1. 실험 재현을 위한 Seed 고정 (가장 맨 위에 둬야 함)
import os
import random
import numpy as np
import tensorflow as tf

os.environ['PYTHONHASHSEED'] = '42'
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)
tf.config.experimental.enable_op_determinism()  # TensorFlow 2.9 이상에서만

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import random

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers, models, Input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, ReLU, GlobalAveragePooling1D, Dense, Dropout

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA

from scipy.stats import mode
from scipy import stats
from datetime import timedelta
from tqdm import tqdm

# Note: Set the file path associated with the dataset.
challenge2025_dataset_path = CONFIG["data_root"]

# To print the list of data items
print("challenge 2025 dataset " + "="*5,'\n')
for file_name in sorted(os.listdir(challenge2025_dataset_path)):
    if file_name.endswith('.parquet'):
        print(file_name)
# Out:
# challenge 2025 dataset =====
#
# ch2025_mACStatus.parquet
# ch2025_mActivity.parquet
# ch2025_mAmbience.parquet
# ch2025_mBle.parquet
# ch2025_mGps.parquet
# ch2025_mLight.parquet
# ch2025_mScreenStatus.parquet
# ch2025_mUsageStats.parquet
# ch2025_mWifi.parquet
# ch2025_wHr.parquet
# ch2025_wLight.parquet
# ch2025_wPedo.parquet

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ### 1. mACStatus, 1분당 1회

# %%
data_item = "mACStatus"  # 스마트폰 충전 여부
input1 = pd.read_parquet(os.path.join(challenge2025_dataset_path, f"ch2025_{data_item}.parquet"))
acstatus_ohe = pd.get_dummies(input1['m_charging'], prefix='charging').astype(int)

# 기존 데이터와 결합 (subject_id, timestamp 유지)
input1 = pd.concat([input1[['subject_id', 'timestamp']], acstatus_ohe], axis=1)

# %% [markdown]
# ### 2. mActivity,  1분당 1회

# %%
data_item = "mActivity" # 사용자 활동 상태
input2 = pd.read_parquet(os.path.join(challenge2025_dataset_path, f"ch2025_{data_item}.parquet"))

# 원-핫 인코딩 수행
activity_ohe = pd.get_dummies(input2['m_activity'], prefix='activity').astype(int)

# 기존 데이터와 결합 (subject_id, timestamp 유지)
input2 = pd.concat([input2[['subject_id', 'timestamp']], activity_ohe], axis=1)

# %% [markdown]
# ### 3. mAmbience, 2분당 1회

# %%
data_item = "mAmbience"  # 주변 소음 데이터
input3 = pd.read_parquet(os.path.join(challenge2025_dataset_path, f"ch2025_{data_item}.parquet"))

# timestamp 초단위 제거 (초를 0초로)
input3['timestamp'] = input3['timestamp'].dt.floor('min')

# 전체 key 수집
all_keys = set()
for row in input3['m_ambience']:
    for item in row:
        all_keys.add(item[0])

key_list = sorted(all_keys)
key_to_index = {key: idx for idx, key in enumerate(key_list)}
vector_length = len(key_list)

# key-value → 확률 벡터 변환 함수
def ambience_to_vector(row):
    vec = np.zeros(vector_length, dtype=np.float32)
    for item in row:
        key, value = item
        if key in key_to_index:
            vec[key_to_index[key]] = float(value)
    return vec

# 변환 적용
ambience_vectors = np.stack(input3['m_ambience'].apply(ambience_to_vector))
ambience_df = pd.DataFrame(ambience_vectors, columns=[f"amb_{k}" for k in key_list], index=input3.index)

# PCA 적용
amb_data = ambience_df.values
pca = PCA(n_components=10, random_state=42)
amb_pca = pca.fit_transform(amb_data)
pca_cols = [f'amb_pca_{i}' for i in range(1, 11)]
amb_pca_df = pd.DataFrame(amb_pca, columns=pca_cols, index=input3.index)

# subject_id, timestamp와 결합
input3 = pd.concat([input3[['subject_id', 'timestamp']], amb_pca_df], axis=1)

# %% [markdown]
# ### 4. mBLE, 10분당 1회

# %%
# Step 0: Load parquet
data_item = "mBle"
input4 = pd.read_parquet(os.path.join(challenge2025_dataset_path, f"ch2025_{data_item}.parquet"))

# Step 1: m_ble explode + 정리
exploded = input4.explode('m_ble').reset_index(drop=True)
ble_df = pd.json_normalize(exploded['m_ble'])

# Step 2: subject_id, timestamp 복원
ble_df['subject_id'] = exploded['subject_id']
ble_df['timestamp'] = exploded['timestamp']

# Step 3: RSSI 수치 정제 및 통계 요약
ble_df['rssi'] = ble_df['rssi'].astype(float)
ble_stats = ble_df.groupby(['subject_id', 'timestamp'])['rssi'].agg(
    ble_rssi_mean='mean',
    ble_rssi_std='std',
    ble_rssi_min='min',
    ble_rssi_max='max',
    ble_rssi_count='count'
).reset_index()

# Step 4: device_class One-hot 인코딩 + 평균 집계
device_ohe = pd.get_dummies(ble_df['device_class'], prefix='ble_device_class').astype(int)
ble_df = pd.concat([ble_df, device_ohe], axis=1)
device_class_agg = ble_df.groupby(['subject_id', 'timestamp'])[device_ohe.columns].mean().reset_index()

# Step 5: address 고유 개수 count
address_count = ble_df.groupby(['subject_id', 'timestamp'])['address'].nunique().reset_index()
address_count = address_count.rename(columns={'address': 'ble_device_unique_count'})

# Step 6: 병합
input4_cnn = ble_stats.merge(device_class_agg, on=['subject_id', 'timestamp'], how='outer')
input4_cnn = input4_cnn.merge(address_count, on=['subject_id', 'timestamp'], how='outer')
input4_cnn = input4_cnn.fillna(0)

# Step 7: RSSI 통계 정규화 (z-score)
rssi_cols = ['ble_rssi_mean', 'ble_rssi_std', 'ble_rssi_min', 'ble_rssi_max', 'ble_rssi_count']
scaler = StandardScaler()
input4_cnn[rssi_cols] = scaler.fit_transform(input4_cnn[rssi_cols])

# Step 8: device_class OHE → PCA(5차원 축소)
device_ohe_cols = [col for col in input4_cnn.columns if col.startswith('ble_device_class_')]
device_ohe_data = input4_cnn[device_ohe_cols]

pca = PCA(n_components=5, random_state=42)
device_pca = pca.fit_transform(device_ohe_data)
pca_cols = [f'ble_device_pca_{i+1}' for i in range(5)]
device_pca_df = pd.DataFrame(device_pca, columns=pca_cols, index=input4_cnn.index)

# Step 9: PCA 결과 붙이기 + 기존 OHE 제거
input4_cnn = pd.concat([input4_cnn.drop(columns=device_ohe_cols), device_pca_df], axis=1)

# Step 10: ble_device_unique_count 정규화 (0~1 스케일)
scaler = StandardScaler()
input4_cnn['ble_device_unique_count'] = scaler.fit_transform(input4_cnn[['ble_device_unique_count']])
input4 = input4_cnn

# %% [markdown]
# ### 5. mGps

# %%
data_item = "mGps"  # 스마트폰으로 측정된 GPS 데이터, 위치 데이터
input5 = pd.read_parquet(os.path.join(challenge2025_dataset_path, f"ch2025_{data_item}.parquet"))

# Step 1: m_gps 속도 평균 계산
def compute_speed_mean(mgps_list):
    if not isinstance(mgps_list, (list, np.ndarray)) or len(mgps_list) == 0:
        return np.nan
    speeds = [point.get('speed', 0) for point in mgps_list if isinstance(point, dict) and 'speed' in point]
    if not speeds:
        return np.nan
    return np.mean(speeds)

input5['speed_mean'] = input5['m_gps'].apply(compute_speed_mean)

# Step 2: m_gps 열 삭제 + NaN 제거
input5 = input5[['subject_id', 'timestamp', 'speed_mean']]
input5 = input5.dropna(subset=['speed_mean'])

# Step 3: speed_mean 클리핑 (10m/s 초과 값 10으로 고정)
input5['speed_mean'] = input5['speed_mean'].clip(upper=10)

# Step 4: speed_mean에 Z-Score 정규화 적용
scaler = StandardScaler()
input5['speed_zscore'] = scaler.fit_transform(input5[['speed_mean']])

# %% [markdown]
# ### 6. mLight, 10분당 1회

# %%
data_item = "mLight"  # 주변 밝기 수준 (Lux)
input6 = pd.read_parquet(os.path.join(challenge2025_dataset_path, f"ch2025_{data_item}.parquet"))

# Step 1: 로그 변환
input6['m_light_log'] = np.log1p(input6['m_light'])

# Step 2: Z-Score 정규화
scaler = StandardScaler()
input6['m_light_zscore'] = scaler.fit_transform(input6[['m_light_log']])

# Step 3: 최종 CNN 입력용 컬럼 정리
input6 = input6[['subject_id', 'timestamp', 'm_light_zscore']]

# %% [markdown]
# ### 7. mScreenStatus, 1분당 1회

# %%
data_item = "mScreenStatus"  # 스마트폰 화면 켜짐 여부
input7 = pd.read_parquet(os.path.join(challenge2025_dataset_path, f"ch2025_{data_item}.parquet"))

# One-Hot Encoding
screen_ohe = pd.get_dummies(input7['m_screen_use'], prefix='screen').astype(int)

# 최종 정제: m_screen_use도 남기고 OHE도 추가
input7 = pd.concat([input7[['subject_id', 'timestamp']], screen_ohe], axis=1)

# %% [markdown]
# ### 8. mUsageStats, 10분당 1회

# %%
data_item = "mUsageStats" # 10분간 어플 사용정보
input8 = pd.read_parquet(os.path.join(challenge2025_dataset_path, f"ch2025_{data_item}.parquet"))

# 어플사용시간 비율/10분
def calc_usage_ratio(app_list):
    if not isinstance(app_list, (list, np.ndarray)) or len(app_list) == 0:
        return np.nan
    total_time = sum(item.get('total_time', 0) for item in app_list)
    return (total_time/600000) / len(app_list)
input8['usage_ratio'] = input8['m_usage_stats'].apply(calc_usage_ratio)

# 편향되어있어서 Min-Max 정규화
# Min-Max 정규화
min_val = input8['usage_ratio'].min()
max_val = input8['usage_ratio'].max()
input8['usage_ratio_norm'] = (input8['usage_ratio'] - min_val) / (max_val - min_val)
input8 = input8.drop(columns=['m_usage_stats','usage_ratio'])

# %% [markdown]
# ### 9. mWifi, 10분당 1회

# %%
data_item = "mWifi"
input9 = pd.read_parquet(os.path.join(challenge2025_dataset_path, f"ch2025_{data_item}.parquet"))

# Step 1: m_wifi explode + 정리
exploded = input9.explode('m_wifi').reset_index(drop=True)
wifi_df = pd.json_normalize(exploded['m_wifi'])

# Step 2: subject_id, timestamp 복원
wifi_df['subject_id'] = exploded['subject_id']
wifi_df['timestamp'] = exploded['timestamp']

# Step 3: RSSI 수치 정제 및 통계 요약
wifi_df['rssi'] = wifi_df['rssi'].astype(float)
wifi_stats = wifi_df.groupby(['subject_id', 'timestamp'])['rssi'].agg(
    wifi_rssi_mean='mean',
    wifi_rssi_std='std',
    wifi_rssi_min='min',
    wifi_rssi_max='max',
    wifi_rssi_count='count'
).reset_index()

# Step 4: 상위 100개 BSSID만 One-hot 인코딩 + 평균 집계
top_bssid = wifi_df['bssid'].value_counts().sort_index().head(100).index
wifi_df['bssid_top'] = wifi_df['bssid'].where(wifi_df['bssid'].isin(top_bssid), 'OTHER')

bssid_ohe = pd.get_dummies(wifi_df['bssid_top'], prefix='bssid').astype(int)
wifi_df = pd.concat([wifi_df, bssid_ohe], axis=1)
bssid_agg = wifi_df.groupby(['subject_id', 'timestamp'])[bssid_ohe.columns].mean().reset_index()

# Step 5: 고유 BSSID 개수 count
bssid_count = wifi_df.groupby(['subject_id', 'timestamp'])['bssid'].nunique().reset_index()
bssid_count = bssid_count.rename(columns={'bssid': 'bssid_count'})

# Step 6: 병합
input9_cnn = wifi_stats.merge(bssid_agg, on=['subject_id', 'timestamp'], how='outer')
input9_cnn = input9_cnn.merge(bssid_count, on=['subject_id', 'timestamp'], how='outer')
input9_cnn = input9_cnn.fillna(0)

# Step 7: RSSI 관련 통계 정규화 (z-score)
rssi_cols = ['wifi_rssi_mean', 'wifi_rssi_std', 'wifi_rssi_min', 'wifi_rssi_max', 'wifi_rssi_count']
scaler = StandardScaler()
input9_cnn[rssi_cols] = scaler.fit_transform(input9_cnn[rssi_cols])

# Step 8: bssid 컬럼 이름 정리 → bssid_1 ~ bssid_100, bssid_OTHER
bssid_cols = [col for col in input9_cnn.columns if col.startswith('bssid_')]
other_col = [col for col in bssid_cols if col.endswith('OTHER')]
top_cols = sorted(set(bssid_cols) - set(other_col))

rename_map = {col: f"bssid_{i+1}" for i, col in enumerate(top_cols)}
if other_col:
    rename_map[other_col[0]] = 'bssid_OTHER'

input9_cnn = input9_cnn.rename(columns=rename_map)

# Step 9: PCA 적용 대상 컬럼 찾기
pca_input_cols = [col for col in input9_cnn.columns if col.startswith('bssid_')]

# Step 10: PCA 적용 (예: 10차원으로 축소)
pca = PCA(n_components=10, random_state=42)
bssid_pca = pca.fit_transform(input9_cnn[pca_input_cols])
pca_cols = [f'bssid_pca_{i+1}' for i in range(10)]
bssid_pca_df = pd.DataFrame(bssid_pca, columns=pca_cols, index=input9_cnn.index)

# Step 11: PCA 결과 붙이기 + 기존 OHE 제거
input9 = pd.concat([input9_cnn.drop(columns=pca_input_cols), bssid_pca_df], axis=1)

# %% [markdown]
# ### 10. wHr

# %%
# Step 1: 심박수 데이터 로드
data_item = "wHr"  # 심박수
input10 = pd.read_parquet(os.path.join(challenge2025_dataset_path, f"ch2025_{data_item}.parquet"))

# Step 2: 심박수 통계 계산 함수 (이상치 필터링 포함)
def calc_hr_stats_filtered(hr_list):
    if not isinstance(hr_list, (list, np.ndarray)) or len(hr_list) == 0:
        return pd.Series([np.nan] * 5)
    valid = [x for x in hr_list if 40 <= x <= 200]
    if len(valid) == 0:
        return pd.Series([np.nan] * 5)
    min_hr = np.min(valid)
    mean_hr = np.mean(valid)
    median_hr = np.median(valid)
    mode_result = stats.mode(valid, keepdims=True)
    mode_hr = mode_result.mode[0] if mode_result.count[0] > 0 else np.nan
    max_hr = np.max(valid)
    return pd.Series([min_hr, mean_hr, median_hr, mode_hr, max_hr])

# Step 3: 통계 컬럼 생성
input10[['min_hr', 'mean_hr', 'median_hr', 'mode_hr', 'max_hr']] = input10['heart_rate'].apply(calc_hr_stats_filtered)

# Step 4: NaN 제거
input10 = input10.dropna(subset=['mean_hr'])

# Step 5: heart_rate 컬럼 제거
input10 = input10.drop(columns='heart_rate')

# Step 6: Z-Score 정규화
hr_cols = ['min_hr', 'mean_hr', 'median_hr', 'mode_hr', 'max_hr']
scaler = StandardScaler()
input10_zscore = scaler.fit_transform(input10[hr_cols])

# Step 7: 정규화된 결과를 DataFrame에 넣기
input10_zscore = pd.DataFrame(input10_zscore, columns=[f'{col}_zscore' for col in hr_cols], index=input10.index)

# Step 8: 원본 min/mean/median/mode/max 컬럼 삭제 후 zscore 컬럼 붙이기
input10 = pd.concat([input10[['subject_id', 'timestamp']], input10_zscore], axis=1)

# %% [markdown]
# ### 11. wLight, 1분당 1회

# %%
data_item = "wLight"
input11 = pd.read_parquet(os.path.join(challenge2025_dataset_path, f"ch2025_{data_item}.parquet"))

# Step 1: 로그 변환
input11['w_light_log'] = np.log1p(input11['w_light'])

# Step 2: Z-Score 정규화
scaler = StandardScaler()
input11['w_light_zscore'] = scaler.fit_transform(input11[['w_light_log']])

# Step 3: 최종 CNN 입력용 컬럼만 유지
input11_cnn = input11[['subject_id', 'timestamp', 'w_light_zscore']]
input11 = input11_cnn

# %% [markdown]
# ### 12. wPedo, 1분당 1회

# %%
data_item = "wPedo"
input12 = pd.read_parquet(os.path.join(challenge2025_dataset_path, f"ch2025_{data_item}.parquet"))

# 빈 열, 이상치 제거
input12 = input12.drop(columns=['running_step', 'walking_step'])
input12 = input12[input12['burned_calories'] <= 15]

# 정규화
features_to_norm = ['step', 'step_frequency', 'distance', 'speed', 'burned_calories']
# log1p 적용
for col in features_to_norm:
    input12[f'{col}_log'] = np.log1p(input12[col])
# Min-Max 정규화
for col in features_to_norm:
    log_col = f'{col}_log'
    min_val = input12[log_col].min()
    max_val = input12[log_col].max()
    input12[f'{col}_norm'] = (input12[log_col] - min_val) / (max_val - min_val)

input12_cnn = input12[['subject_id', 'timestamp'] + [f'{col}_norm' for col in features_to_norm]]
input12 = input12_cnn

# %% [markdown]
# # Train.csv, Input Data 구조 설정

# %%
# 레이블 로딩
df_label = pd.read_csv(CONFIG["train_label_path"])
df_label['lifelog_date'] = pd.to_datetime(df_label['lifelog_date'])
df_label['sleep_date'] = pd.to_datetime(df_label['sleep_date'])

# feature 구조 정의 (21개 피처)
feature_structure = {
    'input1': ['charging_0', 'charging_1'],
    'input2': ['activity_0','activity_1','activity_3','activity_4','activity_7','activity_8'],
    'input3': ['amb_pca_1','amb_pca_2','amb_pca_3','amb_pca_4','amb_pca_5','amb_pca_6','amb_pca_7','amb_pca_8','amb_pca_9','amb_pca_10'],

    'input4': ['ble_rssi_mean','ble_rssi_std','ble_rssi_min','ble_rssi_max','ble_rssi_count','ble_device_unique_count',
               'ble_device_pca_1','ble_device_pca_2','ble_device_pca_3','ble_device_pca_4','ble_device_pca_5'],
    'input5': ['speed_mean','speed_zscore'],
    'input6': ['m_light_zscore'],

    'input7': ['screen_0','screen_1'],
    'input8': ['usage_ratio_norm'],
    'input9': ['wifi_rssi_mean','wifi_rssi_std','wifi_rssi_min','wifi_rssi_max','wifi_rssi_count',
               'bssid_pca_1','bssid_pca_2','bssid_pca_3','bssid_pca_4','bssid_pca_5',
               'bssid_pca_6','bssid_pca_7','bssid_pca_8','bssid_pca_9','bssid_pca_10'],

    'input10': ['min_hr_zscore','mean_hr_zscore','median_hr_zscore','mode_hr_zscore','max_hr_zscore'],
    'input11': ['w_light_zscore'],
    'input12': ['step_norm','step_frequency_norm','distance_norm','speed_norm','burned_calories_norm']
}

# 병합 함수 정의
def merge_input_timeseries(subject_id, lifelog_date, sleep_date, input_dict):
    start = pd.to_datetime(lifelog_date) + timedelta(hours=12)
    end = pd.to_datetime(sleep_date) + timedelta(hours=12)
    base_time = pd.date_range(start=start, end=end, freq='1min')[:-1]

    df_base = pd.DataFrame({'timestamp': base_time})
    merged = df_base.copy()

    for input_name, columns in feature_structure.items():
        df = input_dict[input_name]
        df = df[df['subject_id'] == subject_id].copy()
        df = df.sort_values('timestamp').set_index('timestamp')
        df = df[~df.index.duplicated(keep='last')]
        df = df.reindex(base_time)
        df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간

        for col in columns:
            merged[col] = df[col]

    merged.drop(columns=['timestamp'], inplace=True)
    return merged.fillna(0)

# dict 구조로 안전하게 전달
input_dict = {
    'input1': input1, 'input2': input2, 'input3': input3,
    'input4': input4, 'input5': input5, 'input6': input6,
    'input7': input7, 'input8': input8, 'input9': input9,
    'input10': input10, 'input11': input11, 'input12': input12
}

# %% [markdown]
# # Input 데이터 생성

# %%
# 시계열 생성
X_seq = []
for _, row in tqdm(df_label.iterrows(), total=len(df_label)):
    x = merge_input_timeseries(row['subject_id'], row['lifelog_date'], row['sleep_date'], input_dict)
    X_seq.append(x.values)

X_seq = np.stack(X_seq)
y_target = df_label[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].values
# Out:
#   8%|▊         | 34/450 [00:19<04:20,  1.60it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  17%|█▋        | 77/450 [00:45<03:31,  1.76it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  17%|█▋        | 78/450 [00:46<04:19,  1.43it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  35%|███▍      | 157/450 [01:34<02:43,  1.79it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  42%|████▏     | 189/450 [01:55<03:10,  1.37it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  44%|████▍     | 199/450 [02:01<02:13,  1.89it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  48%|████▊     | 215/450 [02:10<02:16,  1.72it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  49%|████▊     | 219/450 [02:12<02:03,  1.87it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  49%|████▉     | 220/450 [02:13<02:02,  1.88it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  49%|████▉     | 221/450 [02:13<02:00,  1.91it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  50%|████▉     | 223/450 [02:14<01:58,  1.92it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  50%|████▉     | 224/450 [02:15<01:59,  1.90it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  50%|█████     | 225/450 [02:16<01:57,  1.91it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  50%|█████     | 226/450 [02:16<01:57,  1.90it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  50%|█████     | 227/450 [02:17<01:56,  1.92it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  51%|█████     | 228/450 [02:17<01:56,  1.91it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  51%|█████     | 229/450 [02:18<01:59,  1.85it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  51%|█████     | 230/450 [02:18<02:12,  1.66it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  51%|█████▏    | 231/450 [02:19<02:37,  1.39it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  52%|█████▏    | 235/450 [02:22<02:25,  1.48it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  56%|█████▋    | 254/450 [02:34<02:38,  1.24it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  57%|█████▋    | 258/450 [02:36<02:00,  1.60it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  60%|█████▉    | 268/450 [02:42<01:38,  1.84it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  60%|█████▉    | 269/450 [02:42<01:38,  1.83it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  75%|███████▍  | 337/450 [03:23<00:59,  1.91it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  76%|███████▋  | 344/450 [03:28<01:20,  1.32it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  77%|███████▋  | 345/450 [03:29<01:12,  1.45it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  77%|███████▋  | 346/450 [03:29<01:06,  1.56it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  77%|███████▋  | 347/450 [03:30<01:02,  1.64it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  77%|███████▋  | 348/450 [03:30<00:59,  1.71it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  78%|███████▊  | 349/450 [03:31<00:57,  1.75it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  78%|███████▊  | 350/450 [03:31<00:56,  1.78it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  78%|███████▊  | 351/450 [03:32<00:54,  1.81it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  78%|███████▊  | 352/450 [03:32<00:53,  1.85it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  78%|███████▊  | 353/450 [03:33<00:52,  1.86it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  79%|███████▊  | 354/450 [03:33<00:50,  1.89it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  79%|███████▉  | 355/450 [03:34<00:50,  1.88it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  79%|███████▉  | 356/450 [03:34<00:49,  1.91it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  79%|███████▉  | 357/450 [03:35<00:48,  1.91it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  80%|███████▉  | 358/450 [03:35<00:47,  1.92it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  80%|████████  | 360/450 [03:36<00:46,  1.93it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  80%|████████  | 361/450 [03:37<00:46,  1.92it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  80%|████████  | 362/450 [03:37<00:45,  1.94it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  81%|████████  | 363/450 [03:38<00:52,  1.66it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  81%|████████  | 364/450 [03:39<01:01,  1.41it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  81%|████████▏ | 366/450 [03:41<01:07,  1.24it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  82%|████████▏ | 367/450 [03:42<01:00,  1.36it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  82%|████████▏ | 368/450 [03:42<00:55,  1.49it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  82%|████████▏ | 369/450 [03:43<00:50,  1.60it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  82%|████████▏ | 370/450 [03:43<00:47,  1.67it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  83%|████████▎ | 372/450 [03:44<00:43,  1.80it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  83%|████████▎ | 373/450 [03:45<00:41,  1.85it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  83%|████████▎ | 374/450 [03:45<00:40,  1.86it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  83%|████████▎ | 375/450 [03:46<00:39,  1.89it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  86%|████████▌ | 385/450 [03:51<00:41,  1.57it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  86%|████████▌ | 386/450 [03:52<00:47,  1.34it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  86%|████████▌ | 387/450 [03:53<00:51,  1.21it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  86%|████████▌ | 388/450 [03:54<00:53,  1.17it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# 100%|██████████| 450/450 [04:30<00:00,  1.66it/s]

# %%
X_seq.shape
# Out:
# (450, 1440, 61)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from tensorflow.keras.utils import to_categorical

# TimeGAN 모델 클래스
class TimeGAN(tf.keras.Model):
    def __init__(self, seq_length, n_features, hidden_dim=64):
        super(TimeGAN, self).__init__()
        self.seq_length = seq_length
        self.n_features = n_features
        self.hidden_dim = hidden_dim

        # 임베딩 네트워크
        self.embed = layers.LSTM(hidden_dim, return_sequences=True)

        # 생성자
        self.generator_lstm = layers.LSTM(hidden_dim, return_sequences=True)
        self.generator_output = layers.Dense(n_features)  # n_features로 수정

        # 구별자
        self.discriminator_lstm = layers.LSTM(hidden_dim, return_sequences=True)
        self.discriminator_output = layers.Dense(1, activation='sigmoid')

        # 지도 학습 네트워크
        self.supervised_lstm = layers.LSTM(hidden_dim, return_sequences=True)
        self.supervised_output = layers.Dense(1, activation='sigmoid')

    def call(self, inputs, training=False):
        x = self.embed(inputs)

        # 생성자
        generated = self.generator_lstm(x)
        generated = self.generator_output(generated)

        # 구별자
        real_or_fake = self.discriminator_lstm(generated)
        real_or_fake = self.discriminator_output(real_or_fake)

        # 감독 네트워크
        supervised_output = self.supervised_lstm(x)
        supervised_output = self.supervised_output(supervised_output)

        return generated, real_or_fake, supervised_output

# 데이터 생성 및 전처리
def preprocess_data(X_seq):
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X_seq.reshape(-1, X_seq.shape[2]))  # (450 * 1440, 60) 형태로 변환
    X_scaled = X_scaled.reshape(X_seq.shape)  # 다시 (450, 1440, 60) 형태로 복원
    return X_scaled

# 6개 라벨 구조에 맞춰 KMeans 클러스터링 적용
def generate_structured_labels_with_kmeans(generated_data, label_types):
    n_tasks = len(label_types)
    n_samples = generated_data.shape[0]
    labels_matrix = np.zeros((n_samples, n_tasks), dtype=int)

    # Flatten for clustering
    data_flat = generated_data.reshape(n_samples, -1)

    for i, label_type in enumerate(label_types):
        if label_type == 'binary':
            n_clusters = 2
        elif label_type == 'multi3':
            n_clusters = 3
        else:
            raise ValueError(f"Unknown label type: {label_type}")

        km = KMeans(n_clusters=n_clusters, random_state=42)
        cluster_labels = km.fit_predict(data_flat)
        labels_matrix[:, i] = cluster_labels

    return labels_matrix

# TimeGAN 학습 및 데이터 생성
def train_timegan(X_train, seq_length=1440, n_features=61, epochs=100, batch_size=32):
    # TimeGAN 모델 초기화
    model = TimeGAN(seq_length, n_features)
    model.compile(optimizer='adam', loss='binary_crossentropy')

    # 데이터 배치 나누기
    dataset = tf.data.Dataset.from_tensor_slices(X_train).batch(batch_size)

    # 학습 루프
    for epoch in range(epochs):
        for batch in dataset:
            with tf.GradientTape() as tape:
                generated, real_or_fake, supervised_output = model(batch)

                # 손실 계산 (구별자와 생성자)
                discriminator_loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(tf.ones_like(real_or_fake), real_or_fake))
                generator_loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(tf.ones_like(real_or_fake), real_or_fake))

                # 임베딩 및 지도 학습 네트워크 손실
                supervised_loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(tf.ones_like(supervised_output), supervised_output))

                total_loss = discriminator_loss + generator_loss + supervised_loss

            # 모델 업데이트
            grads = tape.gradient(total_loss, model.trainable_variables)
            model.optimizer.apply_gradients(zip(grads, model.trainable_variables))

        print(f'Epoch {epoch+1}/{epochs} - Loss: {total_loss.numpy()}')

    return model

# 데이터 준비 (X_seq는 시계열 데이터)
# 예시로 직접 생성하거나 로드한 데이터 사용
# X_seq = np.load("your_data.npy")  # (450, 1440, 60) 형태

# X_seq를 MinMaxScaler로 정규화
X_scaled = preprocess_data(X_seq)

# 학습 데이터 분할
X_train, X_val = train_test_split(X_scaled, test_size=0.2, shuffle=True)
print(f"훈련 데이터 형태: {X_train.shape}")
print(f"검증 데이터 형태: {X_val.shape}")

# TimeGAN 모델 학습
model = train_timegan(X_train, n_features=61, epochs=100)

# 데이터 생성
n_samples_to_generate = 250
generated_data = model.generator_lstm(X_train[:n_samples_to_generate])
generated_data = model.generator_output(generated_data)

# 생성된 데이터 출력
print("생성된 데이터 형태:", generated_data.shape)

# 6개 라벨 구조 정의
label_types = ['binary', 'binary', 'binary', 'multi3', 'binary', 'binary']  # Q1~Q3, S1, S2~S3

# 새로운 구조화된 라벨 생성
generated_label_matrix = generate_structured_labels_with_kmeans(generated_data.numpy(), label_types)

# 데이터 결합
X_combined = np.concatenate([X_seq, generated_data.numpy()], axis=0)
y_combined = np.concatenate([y_target, generated_label_matrix], axis=0)

print(f"최종 데이터 형태 (원본 + 생성된): {X_combined.shape}")
print(f"최종 라벨 형태 (원본 + 생성된): {y_combined.shape}")
# Out:
# 훈련 데이터 형태: (360, 1440, 61)
# 검증 데이터 형태: (90, 1440, 61)
# Epoch 1/100 - Loss: 0.026677362620830536
# Epoch 2/100 - Loss: 0.0055368756875395775
# Epoch 3/100 - Loss: 0.003621347015723586
# Epoch 4/100 - Loss: 0.003098451066762209
# Epoch 5/100 - Loss: 0.0028732875362038612
# Epoch 6/100 - Loss: 0.002738428767770529
# Epoch 7/100 - Loss: 0.0026373490691184998
# Epoch 8/100 - Loss: 0.0025521982461214066
# Epoch 9/100 - Loss: 0.002476502675563097
# Epoch 10/100 - Loss: 0.0024073992390185595
# Epoch 11/100 - Loss: 0.002343301195651293
# Epoch 12/100 - Loss: 0.0022831668611615896
# Epoch 13/100 - Loss: 0.0022262497805058956
# Epoch 14/100 - Loss: 0.0021719876676797867
# Epoch 15/100 - Loss: 0.0021199469920247793
# Epoch 16/100 - Loss: 0.0020697861909866333
# Epoch 17/100 - Loss: 0.002021234482526779
# Epoch 18/100 - Loss: 0.0019740788266062737
# Epoch 19/100 - Loss: 0.0019281671848148108
# Epoch 20/100 - Loss: 0.0018834249349310994
# Epoch 21/100 - Loss: 0.0018398493994027376
# Epoch 22/100 - Loss: 0.0017974129877984524
# Epoch 23/100 - Loss: 0.0017560123233124614
# Epoch 24/100 - Loss: 0.0017155249370262027
# Epoch 25/100 - Loss: 0.001675845356658101
# Epoch 26/100 - Loss: 0.0016368906944990158
# Epoch 27/100 - Loss: 0.001598596223630011
# Epoch 28/100 - Loss: 0.0015609110705554485
# Epoch 29/100 - Loss: 0.0015237960033118725
# Epoch 30/100 - Loss: 0.001487221335992217
# Epoch 31/100 - Loss: 0.0014511651825159788
# Epoch 32/100 - Loss: 0.0014156135730445385
# Epoch 33/100 - Loss: 0.0013805583585053682
# Epoch 34/100 - Loss: 0.001345996861346066
# Epoch 35/100 - Loss: 0.0013119315262883902
# Epoch 36/100 - Loss: 0.001278368174098432
# Epoch 37/100 - Loss: 0.0012453141389414668
# Epoch 38/100 - Loss: 0.0012127780355513096
# Epoch 39/100 - Loss: 0.0011807674309238791
# Epoch 40/100 - Loss: 0.001149286748841405
# Epoch 100/100 - Loss: 0.0001419758191332221
# 생성된 데이터 형태: (250, 1440, 61)
# 최종 데이터 형태 (원본 + 생성된): (700, 1440, 61)
# 최종 라벨 형태 (원본 + 생성된): (700, 6)

# %%
print(y_target.shape)
print(generated_label_matrix.shape)
# Out:
# (450, 6)

# %% [markdown]
# # Model Compile 모델 구성

# %%
def build_improved_cnn_model(X_seq):
    input_shape = (X_seq.shape[1], X_seq.shape[2])  # 1440, feature 수 자동 추출
    inp = Input(shape=input_shape)

    # Conv Block 1
    x = layers.Conv1D(64, kernel_size=5, strides=2, padding='same')(inp)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    # Conv Block 2
    x = layers.Conv1D(128, kernel_size=5, strides=2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    # Conv Block 3
    x = layers.Conv1D(256, kernel_size=3, strides=2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    # Conv Block 4
    x = layers.Conv1D(512, kernel_size=3, strides=2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.GlobalAveragePooling1D()(x)

    # Dense block
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)

    # Outputs
    out_q1 = layers.Dense(1, activation='sigmoid', name='Q1')(x)
    out_q2 = layers.Dense(1, activation='sigmoid', name='Q2')(x)
    out_q3 = layers.Dense(1, activation='sigmoid', name='Q3')(x)
    out_s1 = layers.Dense(3, activation='softmax', name='S1')(x)
    out_s2 = layers.Dense(1, activation='sigmoid', name='S2')(x)
    out_s3 = layers.Dense(1, activation='sigmoid', name='S3')(x)

    model = models.Model(inputs=inp, outputs=[out_q1, out_q2, out_q3, out_s1, out_s2, out_s3])
    return model

model = build_improved_cnn_model(X_seq)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=7,
    restore_best_weights=True
)

model.compile(
    optimizer=Adam(learning_rate=0.0005),  # learning rate ↓
    loss={
        'Q1': 'binary_crossentropy',
        'Q2': 'binary_crossentropy',
        'Q3': 'binary_crossentropy',
        'S1': 'sparse_categorical_crossentropy',
        'S2': 'binary_crossentropy',
        'S3': 'binary_crossentropy',
    },
    metrics={
        'Q1': ['accuracy'],
        'Q2': ['accuracy'],
        'Q3': ['accuracy'],
        'S1': ['accuracy'],
        'S2': ['accuracy'],
        'S3': ['accuracy']
    }
)

# %% [markdown]
# # Model Fit, 모델학습

# %%
# 데이터 분할 (명시적으로)
X_train, X_val, y_train, y_val = train_test_split(X_combined, y_combined, test_size=0.2, random_state=42)

# 모델 학습습
history = model.fit(
    X_train, {
        'Q1': y_train[:, 0],
        'Q2': y_train[:, 1],
        'Q3': y_train[:, 2],
        'S1': y_train[:, 3],
        'S2': y_train[:, 4],
        'S3': y_train[:, 5]
    },
    validation_data=(X_val, {
        'Q1': y_val[:, 0],
        'Q2': y_val[:, 1],
        'Q3': y_val[:, 2],
        'S1': y_val[:, 3],
        'S2': y_val[:, 4],
        'S3': y_val[:, 5]
    }),
    epochs=100,
    batch_size=32,
    shuffle=False,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 104ms/step - Q1_accuracy: 0.5436 - Q1_loss: 0.6631 - Q2_accuracy: 0.5606 - Q2_loss: 0.6863 - Q3_accuracy: 0.6087 - Q3_loss: 0.6632 - S1_accuracy: 0.4989 - S1_loss: 1.0078 - S2_accuracy: 0.5680 - S2_loss: 0.6702 - S3_accuracy: 0.5956 - S3_loss: 0.6469 - loss: 4.3398 - val_Q1_accuracy: 0.5786 - val_Q1_loss: 0.6812 - val_Q2_accuracy: 0.5286 - val_Q2_loss: 0.6812 - val_Q3_accuracy: 0.6429 - val_Q3_loss: 0.6755 - val_S1_accuracy: 0.3571 - val_S1_loss: 1.0759 - val_S2_accuracy: 0.6857 - val_S2_loss: 0.6763 - val_S3_accuracy: 0.6143 - val_S3_loss: 0.6767 - val_loss: 4.4522
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - Q1_accuracy: 0.8408 - Q1_loss: 0.3292 - Q2_accuracy: 0.8321 - Q2_loss: 0.3691 - Q3_accuracy: 0.8413 - Q3_loss: 0.3361 - S1_accuracy: 0.7243 - S1_loss: 0.5706 - S2_accuracy: 0.8520 - S2_loss: 0.3141 - S3_accuracy: 0.8535 - S3_loss: 0.2979 - loss: 2.2186 - val_Q1_accuracy: 0.7357 - val_Q1_loss: 0.4719 - val_Q2_accuracy: 0.6643 - val_Q2_loss: 0.5751 - val_Q3_accuracy: 0.6929 - val_Q3_loss: 0.5307 - val_S1_accuracy: 0.5786 - val_S1_loss: 0.8756 - val_S2_accuracy: 0.7929 - val_S2_loss: 0.4484 - val_S3_accuracy: 0.7714 - val_S3_loss: 0.4602 - val_loss: 3.3398
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - Q1_accuracy: 0.8614 - Q1_loss: 0.3291 - Q2_accuracy: 0.8416 - Q2_loss: 0.3311 - Q3_accuracy: 0.8577 - Q3_loss: 0.3156 - S1_accuracy: 0.7967 - S1_loss: 0.5553 - S2_accuracy: 0.8275 - S2_loss: 0.3264 - S3_accuracy: 0.8827 - S3_loss: 0.2722 - loss: 2.1320 - val_Q1_accuracy: 0.6643 - val_Q1_loss: 0.6021 - val_Q2_accuracy: 0.6857 - val_Q2_loss: 0.6461 - val_Q3_accuracy: 0.7357 - val_Q3_loss: 0.5659 - val_S1_accuracy: 0.5500 - val_S1_loss: 0.9494 - val_S2_accuracy: 0.7643 - val_S2_loss: 0.4835 - val_S3_accuracy: 0.7643 - val_S3_loss: 0.5322 - val_loss: 3.8478
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - Q1_accuracy: 0.8408 - Q1_loss: 0.3149 - Q2_accuracy: 0.8356 - Q2_loss: 0.3238 - Q3_accuracy: 0.8534 - Q3_loss: 0.2995 - S1_accuracy: 0.7582 - S1_loss: 0.5088 - S2_accuracy: 0.8949 - S2_loss: 0.2794 - S3_accuracy: 0.8928 - S3_loss: 0.2545 - loss: 1.9828 - val_Q1_accuracy: 0.6786 - val_Q1_loss: 0.5200 - val_Q2_accuracy: 0.6929 - val_Q2_loss: 0.5903 - val_Q3_accuracy: 0.7643 - val_Q3_loss: 0.5096 - val_S1_accuracy: 0.5214 - val_S1_loss: 1.0282 - val_S2_accuracy: 0.7500 - val_S2_loss: 0.4799 - val_S3_accuracy: 0.7929 - val_S3_loss: 0.4691 - val_loss: 3.6315

# %% [markdown]
# # Model Prediction, 모델 예측 평가

# %%
# 예측 및 F1 평가
y_pred = model.predict(X_seq)
binary_indices = [0, 1, 2, 4, 5]
y_pred_binary = [(y_pred[i] > 0.5).astype(int).reshape(-1) for i in binary_indices]
y_true_binary = [y_target[:, i] for i in binary_indices]
y_pred_multiclass = np.argmax(y_pred[3], axis=1)
y_true_multiclass = y_target[:, 3]
f1s = [f1_score(y_true_binary[i], y_pred_binary[i], average='macro') for i in range(5)]
f1s.append(f1_score(y_true_multiclass, y_pred_multiclass, average='macro'))
macro_f1_total = np.mean(f1s)

print("📊 Macro F1 Score (전체 평균):", round(macro_f1_total, 5))
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# 📊 Macro F1 Score (전체 평균): 0.54678

# %% [markdown]
# # Submission csv 파일 생성

# %%
df_label = pd.read_csv(CONFIG["submission_sample_path"])

# 시계열 입력 생성
Z_seq = []
for _, row in tqdm(df_label.iterrows(), total=len(df_label)):
    x = x = merge_input_timeseries(row['subject_id'], row['lifelog_date'], row['sleep_date'], input_dict)
    Z_seq.append(x.values)

Z_seq = np.stack(Z_seq)  # shape = (N, 1440, 21)
y_target = df_label[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].values

# 예측
y_pred = model.predict(Z_seq)

# 이진 분류 결과
binary_indices = [0, 1, 2, 4, 5]
y_pred_binary = [(y_pred[i] > 0.5).astype(int).reshape(-1) for i in binary_indices]
y_true_binary = [y_target[:, i] for i in binary_indices]

# 다중 분류 (S1)
y_pred_multiclass = np.argmax(y_pred[3], axis=1)
y_true_multiclass = y_target[:, 3]

# 이진 분류: Q1, Q2, Q3, S2, S3
binary_indices = [0, 1, 2, 4, 5]
y_pred_binary = [(y_pred[i] > 0.5).astype(int).reshape(-1) for i in binary_indices]

# 다중 분류: S1
y_pred_multiclass = np.argmax(y_pred[3], axis=1)

submission_sample = pd.read_csv(CONFIG["submission_sample_path"])

# 결과 입력
submission = submission_sample.copy()
submission['Q1'] = y_pred_binary[0]
submission['Q2'] = y_pred_binary[1]
submission['Q3'] = y_pred_binary[2]
submission['S1'] = y_pred_multiclass
submission['S2'] = y_pred_binary[3]
submission['S3'] = y_pred_binary[4]

# 저장
submission.to_csv(CONFIG["submission_save_path"], index=False)
# Out:
#  37%|███▋      | 93/250 [01:01<01:29,  1.75it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  40%|███▉      | 99/250 [01:04<01:25,  1.76it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  51%|█████     | 128/250 [01:24<01:18,  1.56it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  54%|█████▍    | 135/250 [01:28<01:07,  1.71it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  60%|██████    | 150/250 [01:38<01:02,  1.61it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  73%|███████▎  | 182/250 [01:58<00:38,  1.77it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  73%|███████▎  | 183/250 [01:58<00:38,  1.74it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  74%|███████▎  | 184/250 [01:59<00:46,  1.41it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  74%|███████▍  | 185/250 [02:00<00:52,  1.24it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  74%|███████▍  | 186/250 [02:01<00:55,  1.15it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  75%|███████▍  | 187/250 [02:02<00:50,  1.25it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  75%|███████▌  | 188/250 [02:03<00:44,  1.38it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  76%|███████▌  | 189/250 [02:03<00:40,  1.51it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  76%|███████▌  | 190/250 [02:04<00:37,  1.60it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  76%|███████▋  | 191/250 [02:04<00:35,  1.68it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  77%|███████▋  | 193/250 [02:05<00:32,  1.78it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  78%|███████▊  | 194/250 [02:06<00:31,  1.79it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  78%|███████▊  | 195/250 [02:06<00:30,  1.81it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  78%|███████▊  | 196/250 [02:07<00:30,  1.80it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  80%|███████▉  | 199/250 [02:09<00:27,  1.85it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
#  80%|████████  | 200/250 [02:09<00:26,  1.87it/s]<ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# <ipython-input-27-37b0e0c48b46>:43: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.ffill().bfill().reset_index()  # 앞뒤 모두 보간
# 100%|██████████| 250/250 [02:42<00:00,  1.54it/s]
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
submission.shape
# Out:
# (250, 9)
